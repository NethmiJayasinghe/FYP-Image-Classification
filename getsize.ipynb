# %% [markdown]
# <a href="https://colab.research.google.com/github/NethmiJayasinghe/FYP-Image-Classification/blob/main/getsize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
path='a.jpg'
img=cv2.imread(path)
plt.imshow(mpimg.imread(path))
print(img.shape)
# Out:
# (4048, 3036, 3)

# %%
from google.colab.patches import cv2_imshow

# Load image, grayscale, Gaussian blur, Otsu's threshold
image = cv2.imread("a.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (5,5), 0)
thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# Find bounding box
x,y,w,h = cv2.boundingRect(thresh)
cv2.rectangle(image, (x, y), (x + w, y + h), (36,255,12), 2)
cv2.putText(image, "w={},h={}".format(w,h), (x,y - 10), cv2.FONT_HERSHEY_SIMPLEX, 3, (36,255,12), 2)

cv2_imshow(image)

# %%
print(w,h)
# Out:
# 1455 1876
